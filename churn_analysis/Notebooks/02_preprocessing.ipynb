# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("C:\\Users\\arahm\\Downloads\\data_portfolio\\churn_analysis\\Data\\clean_dataset.csv")

# %%
df_model = df.copy()

# %%
le = LabelEncoder()
for col in df_model.select_dtypes(include='object'):
    df_model[col]= le.fit_transform(df_model[col])
# Out:
# C:\Users\arahm\AppData\Local\Temp\ipykernel_3032\2770967009.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df_model.select_dtypes(include='object'):

# %%
df_model['high_value'] = df_model['high_value'].astype(int)

# %%
X = df_model.drop('Churn', axis=1)
y = df_model['Churn']

# %%
df_model.to_csv("C:\\Users\\arahm\\Downloads\\data_portfolio\\churn_analysis\\Data\\final_ready.csv", index=False)
